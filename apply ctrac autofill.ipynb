# %%
import time
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select
import sys
from pynput.keyboard import Key, Controller
import os

from twocaptcha import TwoCaptcha

api_key = os.getenv('APIKEY_2CAPTCHA', '2a99175556a6a12cf8d2c36be55be7da')
solver = TwoCaptcha(api_key)

df = pd.read_excel('data_crew.xlsx')

link = 'https://rclctrac.com/pages/create_account'
driver = webdriver.Edge()  # Optional argument, if not specified will search path.
for crew_index in range(1, len(df)):
  driver.get(link)

  time.sleep(5) # Let the user actually see something!

  first_name_input = driver.find_element(By.NAME, 'data[PersonalData][first_name]')
  last_name_input = driver.find_element(By.NAME, 'data[PersonalData][last_name]')
  nationality = Select(driver.find_element(By.NAME, 'data[User][country_code]'))
  gender = Select(driver.find_element(By.NAME, 'data[PersonalData][sex]'))
  year_old = driver.find_element(By.ID, 'PersonalData18years1')
  worked_on_ship = driver.find_element(By.ID, 'PersonalDataWorkedOnShip0')
  worked_for_royal = driver.find_element(By.ID, 'PersonalDataWorkedForRoyal0')
  source = Select(driver.find_element(By.NAME, 'data[User][source_id]'))
  email = driver.find_element(By.NAME, 'data[User][email]')
  password = driver.find_element(By.NAME, 'data[User][password]')
  verify_password = driver.find_element(By.NAME, 'data[User][verify_password]')
  submit_btn = driver.find_element(By.ID, 'registerBtn')

  first_name_input.send_keys(df['first_name'][crew_index])
  last_name_input.send_keys(df['last_name'][crew_index])
  nationality.select_by_value('ID')
  if (df['gender'][crew_index] == 'male'):
      gender.select_by_value('1')
  elif (df['gender'][crew_index] == 'female'):
      gender.select_by_value('0')

  year_old.click()
  worked_on_ship.click()
  worked_for_royal.click()
  source.select_by_value('52')
  email.send_keys(df['email'][crew_index])
  password.send_keys(df['password'][crew_index])
  verify_password.send_keys(df['password'][crew_index])

  submit_btn.click()

  time.sleep(5) # Let the user actually see something!

  job_list_btn = driver.find_element(By.LINK_TEXT, 'Go to List of Job Openings')
  job_list_btn.click()

  firefox_skip_btn = driver.find_element(By.ID, 'noThanks')
  firefox_skip_btn.click()

  if (df['position'][crew_index] == 'Commis Cook'):
      position = driver.find_element(By.LINK_TEXT, 'Commis Cook')
      position.click()
  elif (df['position'][crew_index] == 'Galley Steward'):
      position = driver.find_element(By.LINK_TEXT, 'Galley Steward')
      position.click()
  elif (df['position'][crew_index] == 'Restaurant Attendant'):
      position = driver.find_element(By.LINK_TEXT, 'Restaurant Attendant')
      position.click()
  elif (df['position'][crew_index] == 'Assistant Waiter'):
      position = driver.find_element(By.LINK_TEXT, 'Assistant Waiter')
      position.click()
  elif (df['position'][crew_index] == 'Public Area Attendant'):
      position = driver.find_element(By.LINK_TEXT, 'Public Area Attendant')
      position.click()
  elif (df['position'][crew_index] == 'Laundry'):
      position = driver.find_element(By.LINK_TEXT, 'Laundry Attendant')
      position.click()
  elif (df['position'][crew_index] == 'Bar Utility'):
      position = driver.find_element(By.LINK_TEXT, 'Bar Utility')
      position.click()
  elif (df['position'][crew_index] == 'Bar Server'):
      position = driver.find_element(By.LINK_TEXT, 'Bar Server ')
      position.click()

  time.sleep(5)

  apply_btn = driver.find_element(By.CLASS_NAME, 'apply_now')
  apply_btn.click()

  time.sleep(5)

  upload_avatar = driver.find_element(By.XPATH, '//div[@id="upload_avatar"]/span')
  upload_avatar.click()
  # upload_avatar.send_keys(df['foto'][0])

  time.sleep(3)

  keyboard = Controller()
  keyboard.type(df['foto'][crew_index])
  keyboard.press(Key.enter)
  keyboard.release(Key.enter)

  driver.get('https://rclctrac.com/users/upload_resume_form')

  upload_resume_doc = driver.find_element(By.NAME, 'data[UserFile][doc_file]')
  upload_resume_doc.send_keys(df['resume'][crew_index])

  resume_filename = driver.find_element(By.NAME, 'data[UserFile][filename]')
  resume_filename.send_keys('resume')

  submit_resume_btn = driver.find_element(By.XPATH, "//form[@id='UserFileUploadResumeFormForm']/div[@class='button_container']/div[@class='submit']/input[@value='Submit']")
  submit_resume_btn.click()

  time.sleep(5)

  #kembali ke halaman utama profile
  driver.get('https://rclctrac.com/users/crew_home')

  position = driver.find_element(By.LINK_TEXT, 'Click here to Continue')
  position.click()

  if (driver.find_element(By.ID, 'pg_contact_info').get_attribute('class') == ' required completed'):
    pass
  else:
    street_address = driver.find_element(By.NAME, 'data[PersonalData][street_address]')
    street_address.send_keys(df['street_address'][crew_index])

    city = driver.find_element(By.NAME, 'data[PersonalData][city]')
    city.send_keys(df['city'][crew_index])

    country = Select(driver.find_element(By.NAME, 'data[PersonalData][country_code]'))
    country.select_by_value('ID')

    # state1 = driver.find_element(By.NAME, 'data[User][curr_state_code]')
    # state1.click()
    time.sleep(5)
    state2 = Select(driver.find_element(By.NAME, 'data[User][curr_state_code]'))
    state2.select_by_visible_text(df['provinsi'][crew_index])

    kode_pos = driver.find_element(By.NAME, 'data[PersonalData][zip_code]')
    kode_pos.send_keys(str(df['kode_pos'][crew_index]))

    address_from_date = driver.find_element(By.NAME, 'data[PersonalData][address_from_date]')
    address_from_date.send_keys(df['address_from_date'][crew_index])

    address_to_date = driver.find_element(By.NAME, 'data[PersonalData][address_to_date]')
    address_to_date.send_keys(df['address_to_date'][crew_index])

    address_permanent_indicator = driver.find_element(By.ID, 'UserPermanentIndicator')
    address_permanent_indicator.click()

    time.sleep(5)

    airport = Select(driver.find_element(By.NAME, 'data[PersonalData][gateway_id]'))
    airport.select_by_value('421')

    country_code = Select(driver.find_element(By.NAME, 'data[TelephoneData][country_code]'))
    country_code.select_by_value('ID')

    mobile_number = driver.find_element(By.NAME, 'data[TelephoneData][mobile_number]')
    mobile_number.send_keys(str(df['mobile_number'][crew_index]))

    contact_form_btn = driver.find_element(By.ID, 'contact_form_btn')
    contact_form_btn.click()

    time.sleep(5)

  if (driver.find_element(By.ID, 'pg_education').get_attribute('class') == ' completed'):
    pass
  else:
    if (df['tingkat_sekolah'][crew_index] == 'diploma'):
        degree_type = Select(driver.find_element(By.NAME, 'data[EducationRecord][degree_type]'))
        degree_type.select_by_value('32')
    elif (df['tingkat_sekolah'][crew_index] == 'smk' or df['tingkat_sekolah'][crew_index] == 'sma'):
        degree_type = Select(driver.find_element(By.NAME, 'data[EducationRecord][degree_type]'))
        degree_type.select_by_value('23')

    degree_description = driver.find_element(By.NAME, 'data[EducationRecord][degree_description]')
    degree_description.send_keys(df['jurusan'][crew_index])

    school_name = driver.find_element(By.NAME, 'data[EducationRecord][school_name]')
    school_name.send_keys(df['nama_sekolah'][crew_index])

    if (df['tingkat_sekolah'][crew_index] == 'diploma'):
        type_of_school = Select(driver.find_element(By.NAME, 'data[EducationRecord][type_of_school]'))
        type_of_school.select_by_value('3')
    elif (df['tingkat_sekolah'][crew_index] == 'smk'):
        type_of_school = Select(driver.find_element(By.NAME, 'data[EducationRecord][type_of_school]'))
        type_of_school.select_by_value('7')
    elif (df['tingkat_sekolah'][crew_index] == 'sma'):
        type_of_school = Select(driver.find_element(By.NAME, 'data[EducationRecord][type_of_school]'))
        type_of_school.select_by_value('2')

    school_street = driver.find_element(By.NAME, 'data[EducationRecord][school_street]')
    school_street.send_keys(df['alamat_sekolah'][crew_index])

    school_city = driver.find_element(By.NAME, 'data[EducationRecord][school_city]')
    school_city.send_keys(df['kota_sekolah'][crew_index])

    school_country = Select(driver.find_element(By.NAME, 'data[EducationRecord][school_country]'))
    school_country.select_by_value('ID')

    time.sleep(5)

    school_state_code = Select(driver.find_element(By.NAME, 'data[EducationRecord][school_state_code]'))
    school_state_code.select_by_visible_text(df['provinsi_sekolah'][crew_index])

    school_start_month = Select(driver.find_element(By.NAME, 'data[EducationRecord][start_month]'))
    school_start_month.select_by_value('7')

    school_start_year = Select(driver.find_element(By.NAME, 'data[EducationRecord][start_year][year]'))
    school_start_year.select_by_value(str(df['tahun_mulai_sekolah'][crew_index]))

    school_end_month = Select(driver.find_element(By.NAME, 'data[EducationRecord][end_month]'))
    school_end_month.select_by_value('7')

    school_end_year = Select(driver.find_element(By.NAME, 'data[EducationRecord][end_year][year]'))
    school_end_year.select_by_value(str(df['tahun_selesai_sekolah'][crew_index]))

    submit_education_btn = driver.find_element(By.ID, 'submit_education_pop')
    submit_education_btn.click()

    time.sleep(5)

  if (driver.find_element(By.ID, 'pg_employment').get_attribute('class') == ' completed'):
    pass
  else:
    for i in range(1, df['total_experience'][crew_index]+1):
        if (i == 1):
            current_employer = driver.find_element(By.XPATH, "//input[@name='data[EmploymentRecord][current_employer]'][@value='1']")
            current_employer.click()

        employer_name = driver.find_element(By.NAME, 'data[EmploymentRecord][employer_name]')
        employer_name.send_keys(df['nama_tempat_kerja' + str(i)][crew_index])

        industry = Select(driver.find_element(By.NAME, 'data[EmploymentRecord][industry_id]'))
        industry.select_by_visible_text(df['jenis_industri'+ str(i)][crew_index])

        employer_street_address = driver.find_element(By.NAME, 'data[EmploymentRecord][street_address]')
        employer_street_address.send_keys(df['alamat_tempat_kerja'+ str(i)][crew_index])

        employer_city = driver.find_element(By.NAME, 'data[EmploymentRecord][city]')
        employer_city.send_keys(df['kota_tempat_kerja'+ str(i)][crew_index])

        employer_country = Select(driver.find_element(By.NAME, 'data[EmploymentRecord][country_code]'))
        employer_country.select_by_value('ID')

        time.sleep(5)

        employer_state_code = Select(driver.find_element(By.NAME, 'data[EmploymentRecord][emp_state_code]'))
        employer_state_code.select_by_visible_text(df['provinsi_tempat_kerja'+ str(i)][crew_index])

        employer_telephone = driver.find_element(By.NAME, 'data[EmploymentRecord][telephone]')
        employer_telephone.send_keys(str(df['no_telp_tempat_kerja'+ str(i)][crew_index]))

        job_title = driver.find_element(By.NAME, 'data[EmploymentRecord][job_title]')
        job_title.send_keys(df['posisi'+ str(i)][crew_index])

        start_month = Select(driver.find_element(By.NAME, 'data[EmploymentRecord][start_month][month]'))
        start_month.select_by_visible_text(str(df['bulan_mulai'+ str(i)][crew_index]) )# diisi dengan angka, contoh january = 01

        start_year = Select(driver.find_element(By.NAME, 'data[EmploymentRecord][start_year][year]'))
        start_year.select_by_value(str(df['tahun_mulai'+ str(i)][crew_index]))

        if(str(df['bulan_selesai'+ str(i)][crew_index])=='nan'):
            pass
        else:
            end_month = Select(driver.find_element(By.NAME, 'data[EmploymentRecord][end_month][month]'))
            end_month.select_by_visible_text(str(df['bulan_selesai'+ str(i)][crew_index])) # diisi dengan angka, contoh january = 01

        if(str(df['tahun_selesai'+ str(i)][crew_index])=='nan'):
            pass
        else:
            end_year = Select(driver.find_element(By.NAME, 'data[EmploymentRecord][end_year][year]'))
            end_year.select_by_value(str(df['tahun_selesai'+ str(i)][crew_index]))

        hours_per_week = driver.find_element(By.NAME, 'data[EmploymentRecord][hours_per_week]')
        hours_per_week.send_keys('48')

        supervisor_name = driver.find_element(By.NAME, 'data[EmploymentRecord][supervisor_name]')
        supervisor_name.send_keys(df['nama_supervisor'+ str(i)][crew_index])

        supervisor_position = driver.find_element(By.NAME, 'data[EmploymentRecord][supervisor_position]')
        supervisor_position.send_keys(df['posisi_supervisor'+ str(i)][crew_index])

        supervisor_phone = driver.find_element(By.NAME, 'data[EmploymentRecord][supervisor_phone]')
        supervisor_phone.send_keys(str(df['nohp_supervisor'+ str(i)][crew_index]))

        responsibilities = driver.find_element(By.NAME, 'data[EmploymentRecord][responsibilities]')
        responsibilities.send_keys(df['responsibilities'+ str(i)][crew_index])

        add_employment = driver.find_element(By.LINK_TEXT, 'Add Employment')
        add_employment.click()

        time.sleep(5)

    submit_emp_btn = driver.find_element(By.ID, 'submit_emp_pop')
    submit_emp_btn.click()

    time.sleep(5)

  if (driver.find_element(By.ID, 'pg_references').get_attribute('class') == ' required completed'):
    pass
  else:
    reference_first_name = driver.find_element(By.NAME, 'data[PersonReference][reference_first_name]')
    reference_first_name.send_keys(df['reference_first_name'][crew_index])

    reference_last_name = driver.find_element(By.NAME, 'data[PersonReference][reference_last_name]')
    reference_last_name.send_keys(df['reference_last_name'][crew_index])

    reference_company = driver.find_element(By.NAME, 'data[PersonReference][reference_company]')
    reference_company.send_keys(df['nama_tempat_kerja1'][crew_index])

    reference_relation = Select(driver.find_element(By.NAME, 'data[PersonReference][reference_relation_id]'))
    reference_relation.select_by_value('1')

    reference_country = Select(driver.find_element(By.NAME, 'data[PersonReference][reference_country]'))
    reference_country.select_by_value('ID-62')

    reference_phone = driver.find_element(By.NAME, 'data[PersonReference][reference_phone]')
    reference_phone.send_keys(str(df['nohp_supervisor1'][crew_index]))

    submit_reference_btn = driver.find_element(By.ID, 'submit_reference_pop')
    submit_reference_btn.click()

    time.sleep(5)

  if (driver.find_element(By.ID, 'pg_language').get_attribute('class') == ' required completed'):
    pass
  else:
    english_read = driver.find_element(By.ID, "SkillSetCategoryRead33")
    english_read.click()
    english_write = driver.find_element(By.ID, "SkillSetCategoryWrite33")
    english_write.click()
    english_speak = driver.find_element(By.ID, "SkillSetCategorySpeak33")
    english_speak.click()
    english_comprehend = driver.find_element(By.ID, "SkillSetCategoryComprehend33")
    english_comprehend.click()

    submit_language_btn = driver.find_element(By.XPATH, "//fieldset[@class='skills']/div[@class='button_container']/div[@class='submit']/input[@class='button right']")
    submit_language_btn.click()

    time.sleep(5)

  if (driver.find_element(By.ID, 'pg_prescreen_questions').get_attribute('class') == 'completed'):
    pass
  else:
    UserPreScreening1 = driver.find_element(By.ID, "UserPreScreening11")
    UserPreScreening1.click()
    UserPreScreening2 = driver.find_element(By.ID, "UserPreScreening22")
    UserPreScreening2.click()
    UserPreScreening3 = driver.find_element(By.ID, "UserPreScreening32")
    UserPreScreening3.click()
    UserPreScreening4 = driver.find_element(By.ID, "UserPreScreening41")
    UserPreScreening4.click()
    UserPreScreening5 = driver.find_element(By.ID, "UserPreScreening1873")
    UserPreScreening5.click()

    submit_prequestion_btn = driver.find_element(By.ID, "save_prequestion")
    submit_prequestion_btn.click()

    time.sleep(5)

  agreement_signature = driver.find_element(By.NAME, 'data[User][agreement_signature]')
  agreement_signature.send_keys(df['email'][crew_index])

  captcha_img = driver.find_element(By.XPATH, "//img[@alt='captcha']")
  captcha_img_link = captcha_img.get_attribute('src')

  result = solver.normal(captcha_img_link, caseSensitive=1)
  captcha = driver.find_element(By.NAME, 'data[User][captcha]')
  captcha.send_keys(result['code'])

  submit_apply = driver.find_element(By.ID, "submitFinish")
  submit_apply.click()

  time.sleep(5)

  goto_profile_btn = driver.find_element(By.LINK_TEXT, "Go to Profile")
  goto_profile_btn.click()

  driver.get('https://rclctrac.com/users/myinfo')

  time.sleep(15)

  skill_btn = driver.find_element(By.LINK_TEXT, "Skills")
  skill_btn.click()

  time.sleep(5)

  if (df['position'][crew_index] == 'Commis Cook'):
    culinary = driver.find_element(By.XPATH, "//form[@id='SkillSetCategoryDisplayForm']/fieldset[@class='skills']/legend[text()='CULINARY']")
    culinary.click()
    a_la_carte = driver.find_element(By.ID, "SkillSetCategory252")
    a_la_carte.click()
    american_cuisine = driver.find_element(By.ID, "SkillSetCategory2583")
    american_cuisine.click()
    asian_cuisine = driver.find_element(By.ID, "SkillSetCategory2593")
    asian_cuisine.click()
    bulk_cooking = driver.find_element(By.ID, "SkillSetCategory273")
    bulk_cooking.click()
    culinary_management = driver.find_element(By.ID, "SkillSetCategory331")
    culinary_management.click()
    european_cuisine = driver.find_element(By.ID, "SkillSetCategory2622")
    european_cuisine.click()
    fine_dining_cuisine = driver.find_element(By.ID, "SkillSetCategory351")
    fine_dining_cuisine.click()
    food_safety = driver.find_element(By.ID, "SkillSetCategory2633")
    food_safety.click()
    knife_handling = driver.find_element(By.ID, "SkillSetCategory2653")
    knife_handling.click()
    meat_portioning = driver.find_element(By.ID, "SkillSetCategory423")
    meat_portioning.click()
    menu_development = driver.find_element(By.ID, "SkillSetCategory2671")
    menu_development.click()
    sanitation = driver.find_element(By.ID, "SkillSetCategory443")
    sanitation.click()
    saute = driver.find_element(By.ID, "SkillSetCategory2683")
    saute.click()

    general_skills = driver.find_element(By.XPATH, "//form[@id='SkillSetCategoryDisplayForm']/fieldset[@class='skills']/legend[text()='GENERAL SKILLS']")
    general_skills.click()
    sop = driver.find_element(By.ID, "SkillSetCategory2273")
    sop.click()
    time_management = driver.find_element(By.ID, "SkillSetCategory1813")
    time_management.click()
    active_listening = driver.find_element(By.ID, "SkillSetCategory2283")
    active_listening.click()
    analyzing = driver.find_element(By.ID, "SkillSetCategory2293")
    analyzing.click()
    assessing = driver.find_element(By.ID, "SkillSetCategory2302")
    assessing.click()
    cooperative = driver.find_element(By.ID, "SkillSetCategory2313")
    cooperative.click()
    customer_service = driver.find_element(By.ID, "SkillSetCategory182")
    customer_service.click()
    detail_oriented = driver.find_element(By.ID, "SkillSetCategory2323")
    detail_oriented.click()
    effective_comunicating = driver.find_element(By.ID, "SkillSetCategory2333")
    effective_comunicating.click()
    independent = driver.find_element(By.ID, "SkillSetCategory2342")
    independent.click()
    methodical = driver.find_element(By.ID, "SkillSetCategory2353")
    methodical.click()
    organization_skill = driver.find_element(By.ID, "SkillSetCategory2363")
    organization_skill.click()
    problem_solving = driver.find_element(By.ID, "SkillSetCategory2373")
    problem_solving.click()
    public_speaking = driver.find_element(By.ID, "SkillSetCategory2381")
    public_speaking.click()
    teamwork = driver.find_element(By.ID, "SkillSetCategory2393")
    teamwork.click()
    multitasking = driver.find_element(By.ID, "SkillSetCategory4213")
    multitasking.click()
    communication = driver.find_element(By.ID, "SkillSetCategory4222")
    communication.click()
    interpersonal = driver.find_element(By.ID, "SkillSetCategory4233")
    interpersonal.click()
    result_oriented = driver.find_element(By.ID, "SkillSetCategory4243")
    result_oriented.click()
    performance_management = driver.find_element(By.ID, "SkillSetCategory4253")
    performance_management.click()
    presentation = driver.find_element(By.ID, "SkillSetCategory4262")
    presentation.click()
    strategic = driver.find_element(By.ID, "SkillSetCategory4272")
    strategic.click()
    train_the_trainer = driver.find_element(By.ID, "SkillSetCategory4282")
    train_the_trainer.click()

    other = driver.find_element(By.XPATH, "//form[@id='SkillSetCategoryDisplayForm']/fieldset[@class='skills']/legend[text()='Other']")
    other.click()
    # time.sleep(5)
    five_star_property = driver.find_element(By.XPATH, "//div[@class='input select']/div[@class='checkbox']/input[@id='SkillSetCategory243']")
    five_star_property.click()
    haccp = driver.find_element(By.XPATH, "//div[@class='input select']/div[@class='checkbox']/input[@id='SkillSetCategory373']")
    haccp.click()
    usph = driver.find_element(By.XPATH, "//div[@class='input select']/div[@class='checkbox']/input[@id='SkillSetCategory513']")
    usph.click()
  elif (df['position'][crew_index] == 'Public Area'):
    housekeeping = driver.find_element(By.XPATH, "//form[@id='SkillSetCategoryDisplayForm']/fieldset[@class='skills']/legend[text()='FACILITIES/HOUSEKEEPING']")
    housekeeping.click()
    carpet_cleaning = driver.find_element(By.ID, "SkillSetCategory2823")
    carpet_cleaning.click()
    chemical = driver.find_element(By.ID, "SkillSetCategory293")
    chemical.click()
    cleaning_technique = driver.find_element(By.ID, "SkillSetCategory2833")
    cleaning_technique.click()
    dry_cleaning = driver.find_element(By.ID, "SkillSetCategory1012")
    dry_cleaning.click()
    ecolab = driver.find_element(By.ID, "SkillSetCategory1023")
    ecolab.click()
    facilities_management = driver.find_element(By.ID, "SkillSetCategory2842")
    facilities_management.click()
    public_area_maintenance = driver.find_element(By.ID, "SkillSetCategory2893")
    public_area_maintenance.click()
    upholstery = driver.find_element(By.ID, "SkillSetCategory2912")
    upholstery.click()

    general_skills = driver.find_element(By.XPATH, "//form[@id='SkillSetCategoryDisplayForm']/fieldset[@class='skills']/legend[text()='GENERAL SKILLS']")
    general_skills.click()
    sop = driver.find_element(By.ID, "SkillSetCategory2273")
    sop.click()
    time_management = driver.find_element(By.ID, "SkillSetCategory1813")
    time_management.click()
    active_listening = driver.find_element(By.ID, "SkillSetCategory2283")
    active_listening.click()
    analyzing = driver.find_element(By.ID, "SkillSetCategory2293")
    analyzing.click()
    assessing = driver.find_element(By.ID, "SkillSetCategory2302")
    assessing.click()
    cooperative = driver.find_element(By.ID, "SkillSetCategory2313")
    cooperative.click()
    customer_service = driver.find_element(By.ID, "SkillSetCategory183")
    customer_service.click()
    detail_oriented = driver.find_element(By.ID, "SkillSetCategory2323")
    detail_oriented.click()
    effective_comunicating = driver.find_element(By.ID, "SkillSetCategory2333")
    effective_comunicating.click()
    independent = driver.find_element(By.ID, "SkillSetCategory2342")
    independent.click()
    methodical = driver.find_element(By.ID, "SkillSetCategory2353")
    methodical.click()
    organization_skill = driver.find_element(By.ID, "SkillSetCategory2363")
    organization_skill.click()
    problem_solving = driver.find_element(By.ID, "SkillSetCategory2373")
    problem_solving.click()
    public_speaking = driver.find_element(By.ID, "SkillSetCategory2381")
    public_speaking.click()
    teamwork = driver.find_element(By.ID, "SkillSetCategory2393")
    teamwork.click()
    multitasking = driver.find_element(By.ID, "SkillSetCategory4213")
    multitasking.click()
    communication = driver.find_element(By.ID, "SkillSetCategory4223")
    communication.click()
    interpersonal = driver.find_element(By.ID, "SkillSetCategory4233")
    interpersonal.click()
    result_oriented = driver.find_element(By.ID, "SkillSetCategory4243")
    result_oriented.click()
    performance_management = driver.find_element(By.ID, "SkillSetCategory4253")
    performance_management.click()
    presentation = driver.find_element(By.ID, "SkillSetCategory4262")
    presentation.click()
    strategic = driver.find_element(By.ID, "SkillSetCategory4272")
    strategic.click()
    train_the_trainer = driver.find_element(By.ID, "SkillSetCategory4282")
    train_the_trainer.click()

    other = driver.find_element(By.XPATH, "//form[@id='SkillSetCategoryDisplayForm']/fieldset[@class='skills']/legend[text()='Other']")
    other.click()
    # time.sleep(5)
    five_star_property = driver.find_element(By.XPATH, "//div[@class='input select']/div[@class='checkbox']/input[@id='SkillSetCategory243']")
    five_star_property.click()
    hospitality = driver.find_element(By.XPATH, "//div[@class='input select']/div[@class='checkbox']/input[@id='SkillSetCategory382']")
    hospitality.click()

  elif (df['position'][crew_index] == 'Laundry'):
    housekeeping = driver.find_element(By.XPATH, "//form[@id='SkillSetCategoryDisplayForm']/fieldset[@class='skills']/legend[text()='FACILITIES/HOUSEKEEPING']")
    housekeeping.click()
    carpet_cleaning = driver.find_element(By.ID, "SkillSetCategory2822")
    carpet_cleaning.click()
    chemical = driver.find_element(By.ID, "SkillSetCategory293")
    chemical.click()
    cleaning_technique = driver.find_element(By.ID, "SkillSetCategory2833")
    cleaning_technique.click()
    dry_cleaning = driver.find_element(By.ID, "SkillSetCategory1013")
    dry_cleaning.click()
    ecolab = driver.find_element(By.ID, "SkillSetCategory1023")
    ecolab.click()
    laundry = driver.find_element(By.ID, "SkillSetCategory2853")
    laundry.click()
    linenkeeper = driver.find_element(By.ID, "SkillSetCategory2863")
    linenkeeper.click()

    general_skills = driver.find_element(By.XPATH, "//form[@id='SkillSetCategoryDisplayForm']/fieldset[@class='skills']/legend[text()='GENERAL SKILLS']")
    general_skills.click()
    sop = driver.find_element(By.ID, "SkillSetCategory2273")
    sop.click()
    time_management = driver.find_element(By.ID, "SkillSetCategory1813")
    time_management.click()
    active_listening = driver.find_element(By.ID, "SkillSetCategory2283")
    active_listening.click()
    analyzing = driver.find_element(By.ID, "SkillSetCategory2293")
    analyzing.click()
    assessing = driver.find_element(By.ID, "SkillSetCategory2302")
    assessing.click()
    cooperative = driver.find_element(By.ID, "SkillSetCategory2313")
    cooperative.click()
    customer_service = driver.find_element(By.ID, "SkillSetCategory183")
    customer_service.click()
    detail_oriented = driver.find_element(By.ID, "SkillSetCategory2323")
    detail_oriented.click()
    effective_comunicating = driver.find_element(By.ID, "SkillSetCategory2333")
    effective_comunicating.click()
    independent = driver.find_element(By.ID, "SkillSetCategory2342")
    independent.click()
    methodical = driver.find_element(By.ID, "SkillSetCategory2353")
    methodical.click()
    organization_skill = driver.find_element(By.ID, "SkillSetCategory2363")
    organization_skill.click()
    problem_solving = driver.find_element(By.ID, "SkillSetCategory2373")
    problem_solving.click()
    public_speaking = driver.find_element(By.ID, "SkillSetCategory2381")
    public_speaking.click()
    teamwork = driver.find_element(By.ID, "SkillSetCategory2393")
    teamwork.click()
    multitasking = driver.find_element(By.ID, "SkillSetCategory4213")
    multitasking.click()
    communication = driver.find_element(By.ID, "SkillSetCategory4223")
    communication.click()
    interpersonal = driver.find_element(By.ID, "SkillSetCategory4233")
    interpersonal.click()
    result_oriented = driver.find_element(By.ID, "SkillSetCategory4243")
    result_oriented.click()
    performance_management = driver.find_element(By.ID, "SkillSetCategory4253")
    performance_management.click()
    presentation = driver.find_element(By.ID, "SkillSetCategory4262")
    presentation.click()
    strategic = driver.find_element(By.ID, "SkillSetCategory4272")
    strategic.click()
    train_the_trainer = driver.find_element(By.ID, "SkillSetCategory4282")
    train_the_trainer.click()

    other = driver.find_element(By.XPATH, "//form[@id='SkillSetCategoryDisplayForm']/fieldset[@class='skills']/legend[text()='Other']")
    other.click()
    # time.sleep(5)
    five_star_property = driver.find_element(By.XPATH, "//div[@class='input select']/div[@class='checkbox']/input[@id='SkillSetCategory243']")
    five_star_property.click()
    hospitality = driver.find_element(By.XPATH, "//div[@class='input select']/div[@class='checkbox']/input[@id='SkillSetCategory382']")
    hospitality.click()

  elif (df['position'][crew_index] == 'Restaurant Attendant'):
    fb_service = driver.find_element(By.XPATH, "//form[@id='SkillSetCategoryDisplayForm']/fieldset[@class='skills']/legend[text()='FOOD & BEVERAGE SERVICES']")
    fb_service.click()
    heavy_trays = driver.find_element(By.ID, "SkillSetCategory3122")
    heavy_trays.click()
    catering = driver.find_element(By.ID, "SkillSetCategory3193")
    catering.click()
    fine_dining = driver.find_element(By.ID, "SkillSetCategory352")
    fine_dining.click()
    management = driver.find_element(By.ID, "SkillSetCategory941")
    management.click()
    multiple_outlet = driver.find_element(By.ID, "SkillSetCategory861")
    multiple_outlet.click()
    pos = driver.find_element(By.ID, "SkillSetCategory873")
    pos.click()
    sommelier = driver.find_element(By.ID, "SkillSetCategory3222")
    sommelier.click()
    table_service = driver.find_element(By.ID, "SkillSetCategory3233")
    table_service.click()
    wine = driver.find_element(By.ID, "SkillSetCategory3272")
    wine.click()
    food_wine_pairing = driver.find_element(By.ID, "SkillSetCategory4402")
    food_wine_pairing.click()
    servsafe = driver.find_element(By.ID, "SkillSetCategory4423")
    servsafe.click()
    repair = driver.find_element(By.ID, "SkillSetCategory4361")
    repair.click()
    volume_operation = driver.find_element(By.ID, "SkillSetCategory4432")
    volume_operation.click()
    venue = driver.find_element(By.ID, "SkillSetCategory4442")
    venue.click()
    food_alergies = driver.find_element(By.ID, "SkillSetCategory4453")
    food_alergies.click()

    general_skills = driver.find_element(By.XPATH, "//form[@id='SkillSetCategoryDisplayForm']/fieldset[@class='skills']/legend[text()='GENERAL SKILLS']")
    general_skills.click()
    sop = driver.find_element(By.ID, "SkillSetCategory2273")
    sop.click()
    time_management = driver.find_element(By.ID, "SkillSetCategory1813")
    time_management.click()
    active_listening = driver.find_element(By.ID, "SkillSetCategory2283")
    active_listening.click()
    analyzing = driver.find_element(By.ID, "SkillSetCategory2292")
    analyzing.click()
    assessing = driver.find_element(By.ID, "SkillSetCategory2302")
    assessing.click()
    cooperative = driver.find_element(By.ID, "SkillSetCategory2313")
    cooperative.click()
    customer_service = driver.find_element(By.ID, "SkillSetCategory183")
    customer_service.click()
    detail_oriented = driver.find_element(By.ID, "SkillSetCategory2323")
    detail_oriented.click()
    effective_comunicating = driver.find_element(By.ID, "SkillSetCategory2333")
    effective_comunicating.click()
    independent = driver.find_element(By.ID, "SkillSetCategory2343")
    independent.click()
    methodical = driver.find_element(By.ID, "SkillSetCategory2353")
    methodical.click()
    organization_skill = driver.find_element(By.ID, "SkillSetCategory2363")
    organization_skill.click()
    problem_solving = driver.find_element(By.ID, "SkillSetCategory2373")
    problem_solving.click()
    public_speaking = driver.find_element(By.ID, "SkillSetCategory2382")
    public_speaking.click()
    teamwork = driver.find_element(By.ID, "SkillSetCategory2393")
    teamwork.click()
    multitasking = driver.find_element(By.ID, "SkillSetCategory4212")
    multitasking.click()
    communication = driver.find_element(By.ID, "SkillSetCategory4223")
    communication.click()
    interpersonal = driver.find_element(By.ID, "SkillSetCategory4233")
    interpersonal.click()
    result_oriented = driver.find_element(By.ID, "SkillSetCategory4243")
    result_oriented.click()
    performance_management = driver.find_element(By.ID, "SkillSetCategory4253")
    performance_management.click()
    presentation = driver.find_element(By.ID, "SkillSetCategory4262")
    presentation.click()
    strategic = driver.find_element(By.ID, "SkillSetCategory4272")
    strategic.click()
    train_the_trainer = driver.find_element(By.ID, "SkillSetCategory4282")
    train_the_trainer.click()

    other = driver.find_element(By.XPATH, "//form[@id='SkillSetCategoryDisplayForm']/fieldset[@class='skills']/legend[text()='Other']")
    other.click()
    # time.sleep(5)
    five_star_property = driver.find_element(By.XPATH, "//div[@class='input select']/div[@class='checkbox']/input[@id='SkillSetCategory243']")
    five_star_property.click()
    hospitality = driver.find_element(By.XPATH, "//div[@class='input select']/div[@class='checkbox']/input[@id='SkillSetCategory382']")
    hospitality.click()
    haccp = driver.find_element(By.XPATH, "//div[@class='input select']/div[@class='checkbox']/input[@id='SkillSetCategory373']")
    haccp.click()
    usph = driver.find_element(By.XPATH, "//div[@class='input select']/div[@class='checkbox']/input[@id='SkillSetCategory513']")
    usph.click()

  submit_skill_btn = driver.find_element(By.XPATH, "//form[@id='SkillSetCategoryDisplayForm']/div[@class='button_container']/div[@class='submit']/input[@class='button right']")
  submit_skill_btn.click()

  time.sleep(15)

  cert_btn = driver.find_element(By.LINK_TEXT, "Certificates")
  cert_btn.click()

  time.sleep(5)

  if (str(df['passport'][crew_index]) != 'nan'):
    upload_passport_doc = driver.find_element(By.NAME, 'data[UserFile][doc_file]')
    upload_passport_doc.send_keys(df['passport'][crew_index])

    passport_filename = driver.find_element(By.NAME, 'data[UserFile][filename]')
    passport_filename.send_keys('Passport')

    passport_file_type = Select(driver.find_element(By.NAME, 'data[UserFile][type]'))
    passport_file_type.select_by_value('3')

    passport_file_comment = driver.find_element(By.NAME, 'data[UserFile][comments]')
    passport_file_comment.send_keys('Passport')

    submit_passport_btn = driver.find_element(By.XPATH, "//form[@id='UserFileDisplayForm']/div[@class='button_container']/input[@value='Submit']")
    submit_passport_btn.click()

    time.sleep(15)
  else:
    pass

  for i in range(1, df['total_suket'][crew_index]+1):
    if (str(df['suket'+str(i)][crew_index]) != 'nan'):
      upload_suket_doc = driver.find_element(By.NAME, 'data[UserFile][doc_file]')
      upload_suket_doc.send_keys(df['suket'+str(i)][crew_index])

      suket_filename = driver.find_element(By.NAME, 'data[UserFile][filename]')
      suket_filename.send_keys('Certificate of Employment at '+df['nama_tempat_kerja'+str(i)][crew_index])

      suket_file_type = Select(driver.find_element(By.NAME, 'data[UserFile][type]'))
      suket_file_type.select_by_value('3')

      suket_file_comment = driver.find_element(By.NAME, 'data[UserFile][comments]')
      suket_file_comment.send_keys('Certificate of Employment at '+df['nama_tempat_kerja'+str(i)][crew_index])

      submit_suket_btn = driver.find_element(By.XPATH, "//form[@id='UserFileDisplayForm']/div[@class='button_container']/input[@value='Submit']")
      submit_suket_btn.click()

      time.sleep(15)
    else:
      pass

  logout_ctrac = driver.find_element(By.XPATH, '//div[@class="logout"]/a[text()="Logout"]')
  logout_ctrac.click()

  logout_myrcl = driver.find_element(By.XPATH, "//a[@href='/log-out']")
  logout_myrcl.click()

  print("Crew " + df['first_name'][crew_index] + ' ' + df['last_name'][crew_index] + ' Berhasil diapplykan CTRAC')

# %%
import time
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select
import sys
from pynput.keyboard import Key, Controller
import os

from twocaptcha import TwoCaptcha

api_key = os.getenv('APIKEY_2CAPTCHA', '2a99175556a6a12cf8d2c36be55be7da')
solver = TwoCaptcha(api_key)

df = pd.read_excel('data_crew.xlsx')

link = 'https://myrclhome.com/main_login'
driver = webdriver.Edge()  # Optional argument, if not specified will search path.

driver.get(link)

email = driver.find_element(By.NAME, 'UserName')
password = driver.find_element(By.NAME, 'Password')
submit_btn = driver.find_element(By.XPATH, "//div[@class='segment-submit']/input[@type='submit']")

email.send_keys(df['email'][0])
password.send_keys(df['password'][0])

submit_btn.click()

ctrac_btn = driver.find_element(By.XPATH, '//a[@href="/product/c-trac-applicant"]')
ctrac_btn.click()

position = driver.find_element(By.LINK_TEXT, 'Click here to Continue')
position.click()

upload_avatar = driver.find_element(By.XPATH, '//div[@id="upload_avatar"]/span')
upload_avatar.click()
# upload_avatar.send_keys(df['foto'][0])

time.sleep(3)

keyboard = Controller()
keyboard.type(df['foto'][0])
keyboard.press(Key.enter)
keyboard.release(Key.enter)

driver.get('https://rclctrac.com/users/upload_resume_form')

upload_resume_doc = driver.find_element(By.NAME, 'data[UserFile][doc_file]')
upload_resume_doc.send_keys(df['resume'][0])

resume_filename = driver.find_element(By.NAME, 'data[UserFile][filename]')
resume_filename.send_keys('resume')

submit_resume_btn = driver.find_element(By.XPATH, "//form[@id='UserFileUploadResumeFormForm']/div[@class='button_container']/div[@class='submit']/input[@value='Submit']")
submit_resume_btn.click()

time.sleep(5)

#kembali ke halaman utama profile
driver.get('https://rclctrac.com/users/crew_home')

position = driver.find_element(By.LINK_TEXT, 'Click here to Continue')
position.click()

if (driver.find_element(By.ID, 'pg_contact_info').get_attribute('class') == ' required completed'):
  pass
else:
  street_address = driver.find_element(By.NAME, 'data[PersonalData][street_address]')
  street_address.send_keys(df['street_address'][0])

  city = driver.find_element(By.NAME, 'data[PersonalData][city]')
  city.send_keys(df['city'][0])

  country = Select(driver.find_element(By.NAME, 'data[PersonalData][country_code]'))
  country.select_by_value('ID')

  # state1 = driver.find_element(By.NAME, 'data[User][curr_state_code]')
  # state1.click()
  time.sleep(5)
  state2 = Select(driver.find_element(By.NAME, 'data[User][curr_state_code]'))
  state2.select_by_visible_text(df['provinsi'][0])

  kode_pos = driver.find_element(By.NAME, 'data[PersonalData][zip_code]')
  kode_pos.send_keys(str(df['kode_pos'][0]))

  address_from_date = driver.find_element(By.NAME, 'data[PersonalData][address_from_date]')
  address_from_date.send_keys(df['address_from_date'][0])

  address_to_date = driver.find_element(By.NAME, 'data[PersonalData][address_to_date]')
  address_to_date.send_keys(df['address_to_date'][0])

  address_permanent_indicator = driver.find_element(By.ID, 'UserPermanentIndicator')
  address_permanent_indicator.click()

  time.sleep(5)

  airport = Select(driver.find_element(By.NAME, 'data[PersonalData][gateway_id]'))
  airport.select_by_value('421')

  country_code = Select(driver.find_element(By.NAME, 'data[TelephoneData][country_code]'))
  country_code.select_by_value('ID')

  mobile_number = driver.find_element(By.NAME, 'data[TelephoneData][mobile_number]')
  mobile_number.send_keys(str(df['mobile_number'][0]))

  contact_form_btn = driver.find_element(By.ID, 'contact_form_btn')
  contact_form_btn.click()

  time.sleep(5)

if (driver.find_element(By.ID, 'pg_education').get_attribute('class') == ' completed'):
  pass
else:
  if (df['tingkat_sekolah'][0] == 'diploma'):
      degree_type = Select(driver.find_element(By.NAME, 'data[EducationRecord][degree_type]'))
      degree_type.select_by_value('32')
  elif (df['tingkat_sekolah'][0] == 'smk' or df['tingkat_sekolah'][0] == 'sma'):
      degree_type = Select(driver.find_element(By.NAME, 'data[EducationRecord][degree_type]'))
      degree_type.select_by_value('23')

  degree_description = driver.find_element(By.NAME, 'data[EducationRecord][degree_description]')
  degree_description.send_keys(df['jurusan'][0])

  school_name = driver.find_element(By.NAME, 'data[EducationRecord][school_name]')
  school_name.send_keys(df['nama_sekolah'][0])

  if (df['tingkat_sekolah'][0] == 'diploma'):
      type_of_school = Select(driver.find_element(By.NAME, 'data[EducationRecord][type_of_school]'))
      type_of_school.select_by_value('3')
  elif (df['tingkat_sekolah'][0] == 'smk'):
      type_of_school = Select(driver.find_element(By.NAME, 'data[EducationRecord][type_of_school]'))
      type_of_school.select_by_value('7')
  elif (df['tingkat_sekolah'][0] == 'sma'):
      type_of_school = Select(driver.find_element(By.NAME, 'data[EducationRecord][type_of_school]'))
      type_of_school.select_by_value('2')

  school_street = driver.find_element(By.NAME, 'data[EducationRecord][school_street]')
  school_street.send_keys(df['alamat_sekolah'][0])

  school_city = driver.find_element(By.NAME, 'data[EducationRecord][school_city]')
  school_city.send_keys(df['kota_sekolah'][0])

  school_country = Select(driver.find_element(By.NAME, 'data[EducationRecord][school_country]'))
  school_country.select_by_value('ID')

  time.sleep(5)

  school_state_code = Select(driver.find_element(By.NAME, 'data[EducationRecord][school_state_code]'))
  school_state_code.select_by_visible_text(df['provinsi_sekolah'][0])

  school_start_month = Select(driver.find_element(By.NAME, 'data[EducationRecord][start_month]'))
  school_start_month.select_by_value('7')

  school_start_year = Select(driver.find_element(By.NAME, 'data[EducationRecord][start_year][year]'))
  school_start_year.select_by_value(str(df['tahun_mulai_sekolah'][0]))

  school_end_month = Select(driver.find_element(By.NAME, 'data[EducationRecord][end_month]'))
  school_end_month.select_by_value('7')

  school_end_year = Select(driver.find_element(By.NAME, 'data[EducationRecord][end_year][year]'))
  school_end_year.select_by_value(str(df['tahun_selesai_sekolah'][0]))

  submit_education_btn = driver.find_element(By.ID, 'submit_education_pop')
  submit_education_btn.click()

  time.sleep(5)

if (driver.find_element(By.ID, 'pg_employment').get_attribute('class') == ' completed'):
  pass
else:
  for i in range(1, df['total_experience'][0]+1):
      if (i == 1):
          current_employer = driver.find_element(By.XPATH, "//input[@name='data[EmploymentRecord][current_employer]'][@value='1']")
          current_employer.click()

      employer_name = driver.find_element(By.NAME, 'data[EmploymentRecord][employer_name]')
      employer_name.send_keys(df['nama_tempat_kerja' + str(i)][0])

      industry = Select(driver.find_element(By.NAME, 'data[EmploymentRecord][industry_id]'))
      industry.select_by_visible_text(df['jenis_industri'+ str(i)][0])

      employer_street_address = driver.find_element(By.NAME, 'data[EmploymentRecord][street_address]')
      employer_street_address.send_keys(df['alamat_tempat_kerja'+ str(i)][0])

      employer_city = driver.find_element(By.NAME, 'data[EmploymentRecord][city]')
      employer_city.send_keys(df['kota_tempat_kerja'+ str(i)][0])

      employer_country = Select(driver.find_element(By.NAME, 'data[EmploymentRecord][country_code]'))
      employer_country.select_by_value('ID')

      time.sleep(5)

      employer_state_code = Select(driver.find_element(By.NAME, 'data[EmploymentRecord][emp_state_code]'))
      employer_state_code.select_by_visible_text(df['provinsi_tempat_kerja'+ str(i)][0])

      employer_telephone = driver.find_element(By.NAME, 'data[EmploymentRecord][telephone]')
      employer_telephone.send_keys(str(df['no_telp_tempat_kerja'+ str(i)][0]))

      job_title = driver.find_element(By.NAME, 'data[EmploymentRecord][job_title]')
      job_title.send_keys(df['posisi'+ str(i)][0])

      start_month = Select(driver.find_element(By.NAME, 'data[EmploymentRecord][start_month][month]'))
      start_month.select_by_visible_text(str(df['bulan_mulai'+ str(i)][0]) )# diisi dengan angka, contoh january = 01

      start_year = Select(driver.find_element(By.NAME, 'data[EmploymentRecord][start_year][year]'))
      start_year.select_by_value(str(df['tahun_mulai'+ str(i)][0]))

      if(str(df['bulan_selesai'+ str(i)][0])=='nan'):
          pass
      else:
          end_month = Select(driver.find_element(By.NAME, 'data[EmploymentRecord][end_month][month]'))
          end_month.select_by_visible_text(str(df['bulan_selesai'+ str(i)][0])) # diisi dengan angka, contoh january = 01

      if(str(df['tahun_selesai'+ str(i)][0])=='nan'):
          pass
      else:
          end_year = Select(driver.find_element(By.NAME, 'data[EmploymentRecord][end_year][year]'))
          end_year.select_by_value(str(df['tahun_selesai'+ str(i)][0]))

      hours_per_week = driver.find_element(By.NAME, 'data[EmploymentRecord][hours_per_week]')
      hours_per_week.send_keys('48')

      supervisor_name = driver.find_element(By.NAME, 'data[EmploymentRecord][supervisor_name]')
      supervisor_name.send_keys(df['nama_supervisor'+ str(i)][0])

      supervisor_position = driver.find_element(By.NAME, 'data[EmploymentRecord][supervisor_position]')
      supervisor_position.send_keys(df['posisi_supervisor'+ str(i)][0])

      supervisor_phone = driver.find_element(By.NAME, 'data[EmploymentRecord][supervisor_phone]')
      supervisor_phone.send_keys(str(df['nohp_supervisor'+ str(i)][0]))

      responsibilities = driver.find_element(By.NAME, 'data[EmploymentRecord][responsibilities]')
      responsibilities.send_keys(df['responsibilities'+ str(i)][0])

      add_employment = driver.find_element(By.LINK_TEXT, 'Add Employment')
      add_employment.click()

      time.sleep(5)

  submit_emp_btn = driver.find_element(By.ID, 'submit_emp_pop')
  submit_emp_btn.click()

  time.sleep(5)

if (driver.find_element(By.ID, 'pg_references').get_attribute('class') == ' required completed'):
  pass
else:
  reference_first_name = driver.find_element(By.NAME, 'data[PersonReference][reference_first_name]')
  reference_first_name.send_keys(df['reference_first_name'][0])

  reference_last_name = driver.find_element(By.NAME, 'data[PersonReference][reference_last_name]')
  reference_last_name.send_keys(df['reference_last_name'][0])

  reference_company = driver.find_element(By.NAME, 'data[PersonReference][reference_company]')
  reference_company.send_keys(df['nama_tempat_kerja1'][0])

  reference_relation = Select(driver.find_element(By.NAME, 'data[PersonReference][reference_relation_id]'))
  reference_relation.select_by_value('1')

  reference_country = Select(driver.find_element(By.NAME, 'data[PersonReference][reference_country]'))
  reference_country.select_by_value('ID-62')

  reference_phone = driver.find_element(By.NAME, 'data[PersonReference][reference_phone]')
  reference_phone.send_keys(str(df['nohp_supervisor1'][0]))

  submit_reference_btn = driver.find_element(By.ID, 'submit_reference_pop')
  submit_reference_btn.click()

  time.sleep(5)

if (driver.find_element(By.ID, 'pg_language').get_attribute('class') == ' required completed'):
  pass
else:
  english_read = driver.find_element(By.ID, "SkillSetCategoryRead33")
  english_read.click()
  english_write = driver.find_element(By.ID, "SkillSetCategoryWrite33")
  english_write.click()
  english_speak = driver.find_element(By.ID, "SkillSetCategorySpeak33")
  english_speak.click()
  english_comprehend = driver.find_element(By.ID, "SkillSetCategoryComprehend33")
  english_comprehend.click()

  submit_language_btn = driver.find_element(By.XPATH, "//fieldset[@class='skills']/div[@class='button_container']/div[@class='submit']/input[@class='button right']")
  submit_language_btn.click()

  time.sleep(5)

if (driver.find_element(By.ID, 'pg_prescreen_questions').get_attribute('class') == 'completed'):
  pass
else:
  UserPreScreening1 = driver.find_element(By.ID, "UserPreScreening11")
  UserPreScreening1.click()
  UserPreScreening2 = driver.find_element(By.ID, "UserPreScreening22")
  UserPreScreening2.click()
  UserPreScreening3 = driver.find_element(By.ID, "UserPreScreening32")
  UserPreScreening3.click()
  UserPreScreening4 = driver.find_element(By.ID, "UserPreScreening41")
  UserPreScreening4.click()
  UserPreScreening5 = driver.find_element(By.ID, "UserPreScreening1873")
  UserPreScreening5.click()

  submit_prequestion_btn = driver.find_element(By.ID, "save_prequestion")
  submit_prequestion_btn.click()

  time.sleep(5)

agreement_signature = driver.find_element(By.NAME, 'data[User][agreement_signature]')
agreement_signature.send_keys(df['email'][0])

captcha_img = driver.find_element(By.XPATH, "//img[@alt='captcha']")
captcha_img_link = captcha_img.get_attribute('src')

result = solver.normal(captcha_img_link, caseSensitive=1)
captcha = driver.find_element(By.NAME, 'data[User][captcha]')
captcha.send_keys(result['code'])

submit_apply = driver.find_element(By.ID, "submitFinish")
submit_apply.click()

time.sleep(5)

goto_profile_btn = driver.find_element(By.LINK_TEXT, "Go to Profile")
goto_profile_btn.click()

driver.get('https://rclctrac.com/users/myinfo')

time.sleep(15)

skill_btn = driver.find_element(By.LINK_TEXT, "Skills")
skill_btn.click()

time.sleep(5)

if (df['position'][0] == 'Commis Cook'):
  culinary = driver.find_element(By.XPATH, "//form[@id='SkillSetCategoryDisplayForm']/fieldset[@class='skills']/legend[text()='CULINARY']")
  culinary.click()
  a_la_carte = driver.find_element(By.ID, "SkillSetCategory252")
  a_la_carte.click()
  american_cuisine = driver.find_element(By.ID, "SkillSetCategory2583")
  american_cuisine.click()
  asian_cuisine = driver.find_element(By.ID, "SkillSetCategory2593")
  asian_cuisine.click()
  bulk_cooking = driver.find_element(By.ID, "SkillSetCategory273")
  bulk_cooking.click()
  culinary_management = driver.find_element(By.ID, "SkillSetCategory331")
  culinary_management.click()
  european_cuisine = driver.find_element(By.ID, "SkillSetCategory2622")
  european_cuisine.click()
  fine_dining_cuisine = driver.find_element(By.ID, "SkillSetCategory351")
  fine_dining_cuisine.click()
  food_safety = driver.find_element(By.ID, "SkillSetCategory2633")
  food_safety.click()
  knife_handling = driver.find_element(By.ID, "SkillSetCategory2653")
  knife_handling.click()
  meat_portioning = driver.find_element(By.ID, "SkillSetCategory423")
  meat_portioning.click()
  menu_development = driver.find_element(By.ID, "SkillSetCategory2671")
  menu_development.click()
  sanitation = driver.find_element(By.ID, "SkillSetCategory443")
  sanitation.click()
  saute = driver.find_element(By.ID, "SkillSetCategory2683")
  saute.click()

  general_skills = driver.find_element(By.XPATH, "//form[@id='SkillSetCategoryDisplayForm']/fieldset[@class='skills']/legend[text()='GENERAL SKILLS']")
  general_skills.click()
  sop = driver.find_element(By.ID, "SkillSetCategory2273")
  sop.click()
  time_management = driver.find_element(By.ID, "SkillSetCategory1813")
  time_management.click()
  active_listening = driver.find_element(By.ID, "SkillSetCategory2283")
  active_listening.click()
  analyzing = driver.find_element(By.ID, "SkillSetCategory2293")
  analyzing.click()
  assessing = driver.find_element(By.ID, "SkillSetCategory2302")
  assessing.click()
  cooperative = driver.find_element(By.ID, "SkillSetCategory2313")
  cooperative.click()
  customer_service = driver.find_element(By.ID, "SkillSetCategory182")
  customer_service.click()
  detail_oriented = driver.find_element(By.ID, "SkillSetCategory2323")
  detail_oriented.click()
  effective_comunicating = driver.find_element(By.ID, "SkillSetCategory2333")
  effective_comunicating.click()
  independent = driver.find_element(By.ID, "SkillSetCategory2342")
  independent.click()
  methodical = driver.find_element(By.ID, "SkillSetCategory2353")
  methodical.click()
  organization_skill = driver.find_element(By.ID, "SkillSetCategory2363")
  organization_skill.click()
  problem_solving = driver.find_element(By.ID, "SkillSetCategory2373")
  problem_solving.click()
  public_speaking = driver.find_element(By.ID, "SkillSetCategory2381")
  public_speaking.click()
  teamwork = driver.find_element(By.ID, "SkillSetCategory2393")
  teamwork.click()
  multitasking = driver.find_element(By.ID, "SkillSetCategory4213")
  multitasking.click()
  communication = driver.find_element(By.ID, "SkillSetCategory4222")
  communication.click()
  interpersonal = driver.find_element(By.ID, "SkillSetCategory4233")
  interpersonal.click()
  result_oriented = driver.find_element(By.ID, "SkillSetCategory4243")
  result_oriented.click()
  performance_management = driver.find_element(By.ID, "SkillSetCategory4253")
  performance_management.click()
  presentation = driver.find_element(By.ID, "SkillSetCategory4262")
  presentation.click()
  strategic = driver.find_element(By.ID, "SkillSetCategory4272")
  strategic.click()
  train_the_trainer = driver.find_element(By.ID, "SkillSetCategory4282")
  train_the_trainer.click()

  other = driver.find_element(By.XPATH, "//form[@id='SkillSetCategoryDisplayForm']/fieldset[@class='skills']/legend[text()='Other']")
  other.click()
  # time.sleep(5)
  five_star_property = driver.find_element(By.XPATH, "//div[@class='input select']/div[@class='checkbox']/input[@id='SkillSetCategory243']")
  five_star_property.click()
  haccp = driver.find_element(By.XPATH, "//div[@class='input select']/div[@class='checkbox']/input[@id='SkillSetCategory373']")
  haccp.click()
  usph = driver.find_element(By.XPATH, "//div[@class='input select']/div[@class='checkbox']/input[@id='SkillSetCategory513']")
  usph.click()

  submit_skill_btn = driver.find_element(By.XPATH, "//form[@id='SkillSetCategoryDisplayForm']/div[@class='button_container']/div[@class='submit']/input[@class='button right']")
  submit_skill_btn.click()

  time.sleep(15)

cert_btn = driver.find_element(By.LINK_TEXT, "Certificates")
cert_btn.click()

time.sleep(5)

if (str(df['passport'][0]) != 'nan'):
  upload_passport_doc = driver.find_element(By.NAME, 'data[UserFile][doc_file]')
  upload_passport_doc.send_keys(df['passport'][0])

  passport_filename = driver.find_element(By.NAME, 'data[UserFile][filename]')
  passport_filename.send_keys('Passport')

  passport_file_type = Select(driver.find_element(By.NAME, 'data[UserFile][type]'))
  passport_file_type.select_by_value('3')

  passport_file_comment = driver.find_element(By.NAME, 'data[UserFile][comments]')
  passport_file_comment.send_keys('Passport')

  submit_passport_btn = driver.find_element(By.XPATH, "//form[@id='UserFileDisplayForm']/div[@class='button_container']/input[@value='Submit']")
  submit_passport_btn.click()

  time.sleep(15)
else:
   pass

for i in range(1, df['total_suket'][0]+1):
  if (str(df['suket'+str(i)][0]) != 'nan'):
    upload_suket_doc = driver.find_element(By.NAME, 'data[UserFile][doc_file]')
    upload_suket_doc.send_keys(df['suket'+str(i)][0])

    suket_filename = driver.find_element(By.NAME, 'data[UserFile][filename]')
    suket_filename.send_keys('Certificate of Employment at '+df['nama_tempat_kerja'+str(i)][0])

    suket_file_type = Select(driver.find_element(By.NAME, 'data[UserFile][type]'))
    suket_file_type.select_by_value('3')

    suket_file_comment = driver.find_element(By.NAME, 'data[UserFile][comments]')
    suket_file_comment.send_keys('Certificate of Employment at '+df['nama_tempat_kerja'+str(i)][0])

    submit_suket_btn = driver.find_element(By.XPATH, "//form[@id='UserFileDisplayForm']/div[@class='button_container']/input[@value='Submit']")
    submit_suket_btn.click()

    time.sleep(15)
  else:
    pass

logout_ctrac = driver.find_element(By.XPATH, '//div[@class="logout"]/a[text()="Logout"]')
logout_ctrac.click()

logout_myrcl = driver.find_element(By.XPATH, "//a[@href='/log-out']")
logout_myrcl.click()

print("Crew " + df['first_name'][0] + ' ' + df['last_name'][0] + ' Berhasil diapplykan CTRAC')
# Out:
# Crew I Putu Widana Berhasil diapplykan CTRAC

# %%
len(df)
# Out:
# 1

# %%
df = pd.read_excel('data_crew.xlsx')
i=1

if(str(df['bulan_selesai'+ str(i)][0])=='nan'):
    pass
else:
    print(i)
